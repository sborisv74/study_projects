# %%
analyst = 'Anatoly'

# %%
print(analyst)
# Out:
# Anatoly

# %%
years = 2

# %%
has_job = False

# %%
analyst_2 = 'Olga'
years_2 = 3
has_job_2 = True

# %%
analysts = ['Anatoly', 'Olga', 'Beslan']
years = [2, 3, 4]
has_job = [False, True, True]

# %%
print(analysts)
print(years)
print(has_job)
# Out:
# ['Anatoly', 'Olga', 'Beslan']
# [2, 3, 4]
# [False, True, True]

# %%
analysts[0]
# Out:
# 'Anatoly'

# %%
years[2]
# Out:
# 4

# %%
print('Hello, world!')
# Out:
# Hello, world!

# %%
len(analysts)
# Out:
# 3

# %%
len(analysts) > 5
# Out:
# False

# %%
analysts.append('Michael')

# %%
analysts
# Out:
# ['Anatoly', 'Olga', 'Beslan', 'Michael']

# %%
analysts.pop(3)
# Out:
# 'Michael'

# %%
analysts
# Out:
# ['Anatoly', 'Olga', 'Beslan']

# %%
analysts[2] > analysts[1]
# Out:
# False

# %%
has_job = False

# %%
# if has_job == True:
#     happy_message = 'Anatoly is Happy!'
#     print(happy_message)
# else:
#     sad_message = 'Anatoly is Sad ('
#     print(sad_message)
    
# print('New command!')
# --------------- code optimisation ---------------
if has_job:
    message = 'Anatoly is Happy!'
else: # else part is not nesessary
    message = 'Anatoly is Sad ('
print(message)
# Out:
# Anatoly is Sad (

# %%
job_years = 2.8

# %%
salary = 1000

# %%
# if job_years < 1:
#     print('No bonus')
#     new_salary = salary + salary * 0
# elif job_years >= 1 and job_years <= 2:
#     print('20% bonus')
#     new_salary = salary + salary * 0.2
# else:
#     print('40% bonus')
#     new_salary = salary + salary * 0.4
    
# print(new_salary, 'euros')

# --------------- code optimisation ---------------

if job_years < 1:
    coeff = 0
elif job_years >= 1 and job_years <= 2:
    coeff = 0.2
else:
    coeff = 0.4

new_salary = salary + salary * coeff
print(str(coeff * 100) + '% ' + message)
print('Salary after bonus =', new_salary, 'euros')
# Out:
# 40.0% bonus
# Salary after bonus = 1400.0 euros

# %%
message_1 = '{}% bonus'
message_2 = 'Salary after bonus {} euros'

# %%
print(message_1.format(coeff*100))
print(message_2.format(new_salary))
# Out:
# 40.0% bonus
# Salary after bonus 1400.0 euros

# %%
message_3 = '{coeff}% bonus. New salary is {new_salary} euros.'

# %%
print(message_3.format(coeff = coeff * 100, new_salary = new_salary))
# Out:
# 40.0% bonus. New salary is 1400.0 euros.

# %%
analysts = ['Anatoly', 'Olga', 'Beslan']

# %%
for i in analysts:
    if i == 'Anatoly':
        print('Analyst name is {}'.format(i))
# Out:
# Analyst name is Anatoly

# %%
for i in 'analysts':
    if i != 's':
        print('Analyst name is {}'.format(i))
# Out:
# Analyst name is a
# Analyst name is n
# Analyst name is a
# Analyst name is l
# Analyst name is y
# Analyst name is t

# %%
analysts_data = {'Anatoly':[2, 100000], 'Olga':[3, 140000], 'Beslan':[4, 180000]}
analysts_data['Michael'] = [10, 320000]
analysts_data
# Out:
# {'Anatoly': [2, 100000],
#  'Olga': [3, 140000],
#  'Beslan': [4, 180000],
#  'Michael': [10, 320000]}

# %%
for i in analysts_data:
    if analysts_data[i][1] >= 100001:
        print('Next element in dictionary is {i}: \n Value - {v} \n All together - {i} {v} \n'.
              format(i=i, v=analysts_data[i]))
# Out:
# Next element in dictionary is Olga:
#  Value - [3, 140000]
#  All together - Olga [3, 140000]
#
# Next element in dictionary is Beslan:
#  Value - [4, 180000]
#  All together - Beslan [4, 180000]
#
# Next element in dictionary is Michael:
#  Value - [10, 320000]
#  All together - Michael [10, 320000]
